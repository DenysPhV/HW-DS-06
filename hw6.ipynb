# %%
Завдання 1
# Out:
#   Cell In[2], line 1
#     Завдання 1
#              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_openml

# Завантаження датасету 2D
data_2d = pd.read_csv("data/data_2d.csv")

# Завантаження датасету MNIST
mnist = fetch_openml('mnist_784', version=1)
data_mnist = mnist.data

# Для датасету 2D
inertia_2d = []
k_values = range(1, 11) 
for k in k_values:
    kmeans = KMeans(n_clusters=k, n_init=10)
    kmeans.fit(data_2d)
    inertia_2d.append(kmeans.inertia_)

# Для датасету MNIST
inertia_mnist = []
for k in k_values:
    kmeans = KMeans(n_clusters=k, n_init=10)
    kmeans.fit(data_mnist)
    inertia_mnist.append(kmeans.inertia_)

# Побудова графіків методу ліктя
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(k_values, inertia_2d, marker='o', linestyle='-', color='b')
plt.title('Elbow Method for 2D Dataset')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')

plt.subplot(1, 2, 2)
plt.plot(k_values, inertia_mnist, marker='o', linestyle='-', color='r')
plt.title('Elbow Method for MNIST Dataset')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:1022: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
Завдання 2
Візуалізуйте результат роботи кластеризації. Для випадку з mnist датасетом, вам потрібно ще скористатись алгоримтом PCA щоб зменшити 
розмірність вашим даних до 2-вимірного варіанту.
# Out:
#   Cell In[2], line 1
#     Завдання 2
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn.decomposition import PCA

# Завантажити дані MNIST
mnist = fetch_openml("mnist_784", version=1)

# Отримати ознаки та цільові значення
X = mnist.data
y = mnist.target


# Apply PCA to reduce dimensionality to 2D
pca = PCA(n_components=2)
X_2d = pca.fit_transform(X)  # Use your data X

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, n_init=10)  # Replace with the optimal number of clusters
kmeans.fit(X)

# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_2d[:, 0], X_2d[:, 1], c=kmeans.labels_, cmap='viridis')
plt.title("K-means Clustering (2D PCA)")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:1022: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
